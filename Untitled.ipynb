# %%
# !pwd
# Out:
# /c/Users/Usuario/WORKSPACE/DATA_SCIENCE

# %%
pwd
# Out:
# 'C:\\Users\\Usuario\\WORKSPACE\\DATA_SCIENCE'

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
# !python --version
# Out:
# Python 3.9.23

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
x = np.arange(-np.pi, +np.pi, 0.01)
y = np.sin(x)
plt.plot(x, y, color="blue")
